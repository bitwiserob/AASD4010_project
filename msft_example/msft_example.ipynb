# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get all stock info
msft.info

# get historical market data
hist = msft.history(period="1mo")

# show meta information about the history (requires history() to be called first)
msft.history_metadata

# show actions (dividends, splits, capital gains)
msft.actions
msft.dividends
msft.splits
msft.capital_gains  # only for mutual funds & etfs

# show share count
msft.get_shares_full(start="2022-01-01", end=None)

# show financials:
# - income statement
msft.income_stmt
msft.quarterly_income_stmt
# - balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# - cash flow statement
msft.cashflow
msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders
msft.insider_transactions
msft.insider_purchases
msft.insider_roster_holders

# show recommendations
msft.recommendations
msft.recommendations_summary
msft.upgrades_downgrades

# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news
# Out:
# [{'uuid': '4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b',
#   'title': 'Magnificent Seven Stocks To Buy And Watch: Tesla Stock Slides On China Price Cuts',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks-to.html',
#   'providerPublishTime': 1705078362,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/IVY_jviTG_ue49k31izfew--~B/aD02MDA7dz0xMDY1O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#      'width': 1065,
#      'height': 600,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/EDUpiEmpjj.CUhr9H67TBQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NVDA', 'AAPL', 'TSLA', 'META', 'MSFT']},
#  {'uuid': 'a91bb933-54a6-329b-8ec9-5576809a9644',
#   'title': 'So Long, Apple and Tesla. We Built a Better Magnificent 7.',
#   'publisher': 'Barrons.com',
#   'link': 'https://finance.yahoo.com/m/a91bb933-54a6-329b-8ec9-5576809a9644/so-long%2C-apple-and-tesla.-we.html',
#   'providerPublishTime': 1705075620,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/htzwrgHO9d_HZgdxco3Dkw--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/e7e28b64e3c89fcb27416f9e2bb64d76',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/iH2NTvSkk4h6pyN5go.aIA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/e7e28b64e3c89fcb27416f9e2bb64d76',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AAPL', 'TSLA', 'NVDA', 'MSFT', 'AMZN']},
#  {'uuid': '6fb01d77-719e-3e7d-b5ae-2c36ad01a5e4',
#   'title': 'Dow Jones Falls On Cool Inflation Data; Tesla Stock Slides Despite Cathie Wood Buys',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/6fb01d77-719e-3e7d-b5ae-2c36ad01a5e4/dow-jones-falls-on-cool.html',
#   'providerPublishTime': 1705072999,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/HDjemjYlp7Z5vRwiz3dW9Q--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/8e3f0f90c622d76c522be98b9f3975ee',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/udkt6p.2GFTMNRqe6zXG_A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/8e3f0f90c622d76c522be98b9f3975ee',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI',
#    'COMP',
#    'TSLA',
#    '^RUT',
#    'NVO',
#    'NFLX',
#    'AMGN',
#    'AAPL',
#    'MELI',
#    'MSFT',
#    'GOOG']},
#  {'uuid': '84823859-dd8f-37ae-a19e-ade6c2e4a7a2',
#   'title': 'Magnificent Seven Stocks to Give Way to Magnificent Many in 2024',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/magnificent-seven-stocks-way-magnificent-114310501.html',
#   'providerPublishTime': 1705070764,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/J59QIBorhocAKDXByi8jBw--~B/aD02NzU7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/46bd376232bafca6384d53b943f471ba',
#      'width': 1200,
#      'height': 675,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/tNrF_3wCJVglo2UQbunUDg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/46bd376232bafca6384d53b943f471ba',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'AAPL']},
#  {'uuid': 'b8cab1b5-24aa-3c01-80e4-a3f503192256',
#   'title': '14 High Growth NASDAQ Stocks That Are Profitable',
#   'publisher': 'Insider Monkey',
#   'link': 'https://finance.yahoo.com/news/14-high-growth-nasdaq-stocks-143709056.html',
#   'providerPublishTime': 1705070229,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/sSj2OXsjhYinSPl6aQkPfQ--~B/aD0xNDQwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/insidermonkey.com/909f75c9b4d705d8380a2443e4a2797a',
#      'width': 1920,
#      'height': 1440,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/0t5qRmjlCuNcLPoIbP3V3Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/909f75c9b4d705d8380a2443e4a2797a',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['FCNCA',
#    'PODD',
#    'SHLS',
#    'MEDP',
#    'SWAV',
#    'LNTH',
#    'CELH',
#    'GOOG',
#    'PCTY',
#    'ADBE',
#    'MSFT']},
#  {'uuid': 'e49312bd-16ee-3219-8281-79ed22d9732c',
#   'title': 'Dow Jones Futures Fall Amid Big Earnings, Surging Oil Prices; Tesla Cuts Prices',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/e49312bd-16ee-3219-8281-79ed22d9732c/dow-jones-futures-fall-amid.html',
#   'providerPublishTime': 1705065334,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/jlwG6Omyct.9UN0SK0SFSw--~B/aD01NzI7dz0xMDEyO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/bf7a504d3b30b2183c4aea04c9aa4d82',
#      'width': 1012,
#      'height': 572,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/rFsd5x072TF1mxs.HzfoKg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/bf7a504d3b30b2183c4aea04c9aa4d82',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC', '^DJI', 'COMP', 'TSLA', 'NFLX', 'MSFT', 'UNH']},
#  {'uuid': '6a5ea190-b4b1-3a33-bd05-f7788bcc2c2f',
#   'title': 'Stock Market Leaders, Like Microsoft Stock, Exhibit These Characteristics',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/6a5ea190-b4b1-3a33-bd05-f7788bcc2c2f/stock-market-leaders%2C-like.html',
#   'providerPublishTime': 1705064420,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/mzj17CaJvb7MmwndGBs.Hw--~B/aD01NzI7dz0xMDEyO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/020cc38586a9857159d5476031bc35e2',
#      'width': 1012,
#      'height': 572,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/.kvW2zfspdRuyjEO2f3.Dg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/020cc38586a9857159d5476031bc35e2',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '33f7f341-bc8c-366f-abeb-5897b8575045',
#   'title': 'These 2 AI Stocks Could Double in 2024',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/33f7f341-bc8c-366f-abeb-5897b8575045/these-2-ai-stocks-could.html',
#   'providerPublishTime': 1705064400,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Ce3DqxB7t0ac4NyxVc1oNA--~B/aD05MzM7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/f19824a430f607a23a42de496513c8fe',
#      'width': 1400,
#      'height': 933,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/OeLhvzbsVLdoM9fWm6TfXg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/f19824a430f607a23a42de496513c8fe',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['PATH', 'MSFT']}]

# %%
# get all stock info
msft.info

import json




with open("sample.json", "w") as outfile:
    outfile.write()
# Out:
# {'ticker': 'MSFT',
#  'proxy': None,
#  'session': None,
#  '_history':                                  Open        High         Low       Close  \
#  Date
#  2023-12-12 00:00:00-05:00  370.850006  374.420013  370.459991  374.380005
#  2023-12-13 00:00:00-05:00  376.019989  377.640015  370.769989  374.369995
#  2023-12-14 00:00:00-05:00  373.309998  373.760010  364.130005  365.929993
#  2023-12-15 00:00:00-05:00  366.850006  372.399994  366.279999  370.730011
#  2023-12-18 00:00:00-05:00  369.450012  373.000000  368.679993  372.649994
#  2023-12-19 00:00:00-05:00  371.489990  373.260010  369.839996  373.260010
#  2023-12-20 00:00:00-05:00  375.000000  376.029999  370.529999  370.619995
#  2023-12-21 00:00:00-05:00  372.559998  374.410004  370.040009  373.540009
#  2023-12-22 00:00:00-05:00  373.679993  375.179993  372.709991  374.579987
#  2023-12-26 00:00:00-05:00  375.000000  376.940002  373.500000  374.660004
#  2023-12-27 00:00:00-05:00  373.690002  375.059998  372.809998  374.070007
#  2023-12-28 00:00:00-05:00  375.369995  376.459991  374.160004  375.279999
#  2023-12-29 00:00:00-05:00  376.000000  377.160004  373.480011  376.040009
#  2024-01-02 00:00:00-05:00  373.859985  375.899994  366.769989  370.869995
#  2024-01-03 00:00:00-05:00  369.010010  373.260010  368.510010  370.600006
#  2024-01-04 00:00:00-05:00  370.670013  373.100006  367.170013  367.940002
#  2024-01-05 00:00:00-05:00  368.970001  372.059998  366.500000  367.750000
#  2024-01-08 00:00:00-05:00  369.299988  375.200012  369.010010  374.690002
#  2024-01-09 00:00:00-05:00  372.010010  375.989990  371.190002  375.790009
#  2024-01-10 00:00:00-05:00  376.369995  384.170013  376.320007  382.769989
#  2024-01-11 00:00:00-05:00  386.000000  390.679993  380.380005  384.630005
#  2024-01-12 00:00:00-05:00  385.489990  388.480011  384.649994  386.563690
#
#                               Volume  Dividends  Stock Splits
#  Date
#  2023-12-12 00:00:00-05:00  24838300        0.0           0.0
#  2023-12-13 00:00:00-05:00  30955500        0.0           0.0
#  2023-12-14 00:00:00-05:00  43277500        0.0           0.0
#  2023-12-15 00:00:00-05:00  78478200        0.0           0.0
#  2023-12-18 00:00:00-05:00  21802900        0.0           0.0
#  2023-12-19 00:00:00-05:00  20603700        0.0           0.0
#  2023-12-20 00:00:00-05:00  26316700        0.0           0.0
#  2023-12-21 00:00:00-05:00  17708000        0.0           0.0
#  2023-12-22 00:00:00-05:00  17091100        0.0           0.0
#  2023-12-26 00:00:00-05:00  12673100        0.0           0.0
#  2023-12-27 00:00:00-05:00  14905400        0.0           0.0
#  2023-12-28 00:00:00-05:00  14327000        0.0           0.0
#  2023-12-29 00:00:00-05:00  18723000        0.0           0.0
#  2024-01-02 00:00:00-05:00  25258600        0.0           0.0
#  2024-01-03 00:00:00-05:00  23083500        0.0           0.0
#  2024-01-04 00:00:00-05:00  20901500        0.0           0.0
#  2024-01-05 00:00:00-05:00  20987000        0.0           0.0
#  2024-01-08 00:00:00-05:00  23134000        0.0           0.0
#  2024-01-09 00:00:00-05:00  20830000        0.0           0.0
#  2024-01-10 00:00:00-05:00  25514200        0.0           0.0
#  2024-01-11 00:00:00-05:00  27793500        0.0           0.0
#  2024-01-12 00:00:00-05:00   8595356        0.0           0.0  ,
#  '_history_metadata': {'currency': 'USD',
#   'symbol': 'MSFT',
#   'exchangeName': 'NMS',
#   'instrumentType': 'EQUITY',
#   'firstTradeDate': 511108200,
#   'regularMarketTime': 1705078735,
#   'gmtoffset': -18000,
#   'timezone': 'EST',
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketPrice': 386.564,
#   'chartPreviousClose': 374.38,
#   'priceHint': 2,
#   'currentTradingPeriod': {'pre': {'timezone': 'EST',
#     'end': 1705069800,
#     'start': 1705050000,
#     'gmtoffset': -18000},
#    'regular': {'timezone': 'EST',
#     'end': 1705093200,
#     'start': 1705069800,
#     'gmtoffset': -18000},
#    'post': {'timezone': 'EST',
#     'end': 1705107600,
#     'start': 1705093200,
#     'gmtoffset': -18000}},
#   'dataGranularity': '1d',
#   'range': '1mo',
#   'validRanges': ['1d',
#    '5d',
#    '1mo',
#    '3mo',
#    '6mo',
#    '1y',
#    '2y',
#    '5y',
#    '10y',
#    'ytd',
#    'max']},
#  '_history_metadata_formatted': True,
#  '_base_url': 'https://query2.finance.yahoo.com',
#  '_tz': 'America/New_York',
#  '_isin': '-',
#  '_news': [{'uuid': '4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b',
#    'title': 'Magnificent Seven Stocks To Buy And Watch: Tesla Stock Slides On China Price Cuts',
#    'publisher': "Investor's Business Daily",
#    'link': 'https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks-to.html',
#    'providerPublishTime': 1705078362,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/IVY_jviTG_ue49k31izfew--~B/aD02MDA7dz0xMDY1O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#       'width': 1065,
#       'height': 600,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/EDUpiEmpjj.CUhr9H67TBQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['NVDA', 'AAPL', 'TSLA', 'META', 'MSFT']},
#   {'uuid': 'a91bb933-54a6-329b-8ec9-5576809a9644',
#    'title': 'So Long, Apple and Tesla. We Built a Better Magnificent 7.',
#    'publisher': 'Barrons.com',
#    'link': 'https://finance.yahoo.com/m/a91bb933-54a6-329b-8ec9-5576809a9644/so-long%2C-apple-and-tesla.-we.html',
#    'providerPublishTime': 1705075620,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/htzwrgHO9d_HZgdxco3Dkw--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/e7e28b64e3c89fcb27416f9e2bb64d76',
#       'width': 1280,
#       'height': 640,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/iH2NTvSkk4h6pyN5go.aIA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/e7e28b64e3c89fcb27416f9e2bb64d76',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['AAPL', 'TSLA', 'NVDA', 'MSFT', 'AMZN']},
#   {'uuid': '6fb01d77-719e-3e7d-b5ae-2c36ad01a5e4',
#    'title': 'Dow Jones Falls On Cool Inflation Data; Tesla Stock Slides Despite Cathie Wood Buys',
#    'publisher': "Investor's Business Daily",
#    'link': 'https://finance.yahoo.com/m/6fb01d77-719e-3e7d-b5ae-2c36ad01a5e4/dow-jones-falls-on-cool.html',
#    'providerPublishTime': 1705072999,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/HDjemjYlp7Z5vRwiz3dW9Q--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/8e3f0f90c622d76c522be98b9f3975ee',
#       'width': 1000,
#       'height': 563,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/udkt6p.2GFTMNRqe6zXG_A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/8e3f0f90c622d76c522be98b9f3975ee',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['^DJI',
#     'COMP',
#     'TSLA',
#     '^RUT',
#     'NVO',
#     'NFLX',
#     'AMGN',
#     'AAPL',
#     'MELI',
#     'MSFT',
#     'GOOG']},
#   {'uuid': '84823859-dd8f-37ae-a19e-ade6c2e4a7a2',
#    'title': 'Magnificent Seven Stocks to Give Way to Magnificent Many in 2024',
#    'publisher': 'Bloomberg',
#    'link': 'https://finance.yahoo.com/news/magnificent-seven-stocks-way-magnificent-114310501.html',
#    'providerPublishTime': 1705070764,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/J59QIBorhocAKDXByi8jBw--~B/aD02NzU7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/46bd376232bafca6384d53b943f471ba',
#       'width': 1200,
#       'height': 675,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/tNrF_3wCJVglo2UQbunUDg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/46bd376232bafca6384d53b943f471ba',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['MSFT', 'AAPL']},
#   {'uuid': 'b8cab1b5-24aa-3c01-80e4-a3f503192256',
#    'title': '14 High Growth NASDAQ Stocks That Are Profitable',
#    'publisher': 'Insider Monkey',
#    'link': 'https://finance.yahoo.com/news/14-high-growth-nasdaq-stocks-143709056.html',
#    'providerPublishTime': 1705070229,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/sSj2OXsjhYinSPl6aQkPfQ--~B/aD0xNDQwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/insidermonkey.com/909f75c9b4d705d8380a2443e4a2797a',
#       'width': 1920,
#       'height': 1440,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/0t5qRmjlCuNcLPoIbP3V3Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/909f75c9b4d705d8380a2443e4a2797a',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['FCNCA',
#     'PODD',
#     'SHLS',
#     'MEDP',
#     'SWAV',
#     'LNTH',
#     'CELH',
#     'GOOG',
#     'PCTY',
#     'ADBE',
#     'MSFT']},
#   {'uuid': 'e49312bd-16ee-3219-8281-79ed22d9732c',
#    'title': 'Dow Jones Futures Fall Amid Big Earnings, Surging Oil Prices; Tesla Cuts Prices',
#    'publisher': "Investor's Business Daily",
#    'link': 'https://finance.yahoo.com/m/e49312bd-16ee-3219-8281-79ed22d9732c/dow-jones-futures-fall-amid.html',
#    'providerPublishTime': 1705065334,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/jlwG6Omyct.9UN0SK0SFSw--~B/aD01NzI7dz0xMDEyO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/bf7a504d3b30b2183c4aea04c9aa4d82',
#       'width': 1012,
#       'height': 572,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/rFsd5x072TF1mxs.HzfoKg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/bf7a504d3b30b2183c4aea04c9aa4d82',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['^GSPC', '^DJI', 'COMP', 'TSLA', 'NFLX', 'MSFT', 'UNH']},
#   {'uuid': '6a5ea190-b4b1-3a33-bd05-f7788bcc2c2f',
#    'title': 'Stock Market Leaders, Like Microsoft Stock, Exhibit These Characteristics',
#    'publisher': "Investor's Business Daily",
#    'link': 'https://finance.yahoo.com/m/6a5ea190-b4b1-3a33-bd05-f7788bcc2c2f/stock-market-leaders%2C-like.html',
#    'providerPublishTime': 1705064420,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/mzj17CaJvb7MmwndGBs.Hw--~B/aD01NzI7dz0xMDEyO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/020cc38586a9857159d5476031bc35e2',
#       'width': 1012,
#       'height': 572,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/.kvW2zfspdRuyjEO2f3.Dg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/020cc38586a9857159d5476031bc35e2',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['MSFT']},
#   {'uuid': '33f7f341-bc8c-366f-abeb-5897b8575045',
#    'title': 'These 2 AI Stocks Could Double in 2024',
#    'publisher': 'Motley Fool',
#    'link': 'https://finance.yahoo.com/m/33f7f341-bc8c-366f-abeb-5897b8575045/these-2-ai-stocks-could.html',
#    'providerPublishTime': 1705064400,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Ce3DqxB7t0ac4NyxVc1oNA--~B/aD05MzM7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/f19824a430f607a23a42de496513c8fe',
#       'width': 1400,
#       'height': 933,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/OeLhvzbsVLdoM9fWm6TfXg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/f19824a430f607a23a42de496513c8fe',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['PATH', 'MSFT']}],
#  '_shares': None,
#  '_earnings_dates': {12:                            EPS Estimate  Reported EPS  Surprise(%)
#   Earnings Date
#   2024-10-22 06:00:00-04:00           NaN           NaN          NaN
#   2024-07-23 06:00:00-04:00           NaN           NaN          NaN
#   2024-04-23 06:00:00-04:00           NaN           NaN          NaN
#   2024-01-22 16:00:00-05:00          2.53           NaN          NaN
#   2024-01-22 05:00:00-05:00          2.53           NaN          NaN
#   2023-10-24 12:00:00-04:00          2.65          2.99       0.1270
#   2023-07-25 12:00:00-04:00          2.55          2.69       0.0549
#   2023-04-25 12:00:00-04:00          2.23          2.45       0.0981
#   2023-01-24 11:00:00-05:00          2.29          2.32       0.0109
#   2022-10-25 12:00:00-04:00          2.30          2.35       0.0205
#   2022-07-26 12:00:00-04:00          2.29          2.23      -0.0274
#   2022-04-26 12:00:00-04:00          2.19          2.22       0.0160},
#  '_earnings': None,
#  '_financials': None,
#  '_data': <yfinance.data.YfData at 0x206938ab130>,
#  '_analysis': <yfinance.scrapers.analysis.Analysis at 0x206938aa140>,
#  '_holders': <yfinance.scrapers.holders.Holders at 0x206bb077cd0>,
#  '_quote': <yfinance.scrapers.quote.Quote at 0x206bb077f10>,
#  '_fundamentals': <yfinance.scrapers.fundamentals.Fundamentals at 0x206bb077f70>,
#  '_fast_info': None,
#  '_reconstruct_start_interval': None,
#  '_expirations': {'2024-01-12': 1705017600,
#   '2024-01-19': 1705622400,
#   '2024-01-26': 1706227200,
#   '2024-02-02': 1706832000,
#   '2024-02-09': 1707436800,
#   '2024-02-16': 1708041600,
#   '2024-02-23': 1708646400,
#   '2024-03-15': 1710460800,
#   '2024-04-19': 1713484800,
#   '2024-05-17': 1715904000,
#   '2024-06-21': 1718928000,
#   '2024-07-19': 1721347200,
#   '2024-08-16': 1723766400,
#   '2024-09-20': 1726790400,
#   '2024-12-20': 1734652800,
#   '2025-01-17': 1737072000,
#   '2025-06-20': 1750377600,
#   '2025-12-19': 1766102400,
#   '2026-01-16': 1768521600,
#   '2026-06-18': 1781740800},
#  '_underlying': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'EQUITY',
#   'typeDisp': 'Equity',
#   'quoteSourceName': 'Nasdaq Real Time Price',
#   'triggerable': True,
#   'customPriceAlertConfidence': 'HIGH',
#   'currency': 'USD',
#   'marketState': 'REGULAR',
#   'regularMarketChangePercent': 0.5024058,
#   'regularMarketPrice': 386.5624,
#   'exchange': 'NMS',
#   'shortName': 'Microsoft Corporation',
#   'longName': 'Microsoft Corporation',
#   'messageBoardId': 'finmb_21835',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'gmtOffSetMilliseconds': -18000000,
#   'market': 'us_market',
#   'esgPopulated': False,
#   'firstTradeDateMilliseconds': 511108200000,
#   'priceHint': 2,
#   'regularMarketChange': 1.9324036,
#   'regularMarketTime': 1705078739,
#   'regularMarketDayHigh': 388.48,
#   'regularMarketDayRange': '384.65 - 388.48',
#   'regularMarketDayLow': 384.65,
#   'regularMarketVolume': 8596283,
#   'regularMarketPreviousClose': 384.63,
#   'bid': 386.76,
#   'ask': 386.77,
#   'bidSize': 12,
#   'askSize': 9,
#   'fullExchangeName': 'NasdaqGS',
#   'financialCurrency': 'USD',
#   'regularMarketOpen': 385.49,
#   'averageDailyVolume3Month': 26282806,
#   'averageDailyVolume10Day': 22055230,
#   'fiftyTwoWeekLowChange': 155.88242,
#   'fiftyTwoWeekLowChangePercent': 0.6757518,
#   'fiftyTwoWeekRange': '230.68 - 390.68',
#   'fiftyTwoWeekHighChange': -4.117584,
#   'fiftyTwoWeekHighChangePercent': -0.010539532,
#   'fiftyTwoWeekLow': 230.68,
#   'fiftyTwoWeekHigh': 390.68,
#   'fiftyTwoWeekChangePercent': 60.77833,
#   'dividendDate': 1710374400,
#   'earningsTimestamp': 1698183000,
#   'earningsTimestampStart': 1705921140,
#   'earningsTimestampEnd': 1706270400,
#   'trailingAnnualDividendRate': 2.79,
#   'trailingPE': 37.493927,
#   'dividendRate': 3.0,
#   'trailingAnnualDividendYield': 0.007253724,
#   'dividendYield': 0.78,
#   'epsTrailingTwelveMonths': 10.31,
#   'epsForward': 11.79,
#   'epsCurrentYear': 10.25,
#   'priceEpsCurrentYear': 37.713406,
#   'sharesOutstanding': 7432260096,
#   'bookValue': 29.702,
#   'fiftyDayAverage': 370.4004,
#   'fiftyDayAverageChange': 16.162018,
#   'fiftyDayAverageChangePercent': 0.04363391,
#   'twoHundredDayAverage': 333.97964,
#   'twoHundredDayAverageChange': 52.582764,
#   'twoHundredDayAverageChangePercent': 0.15744302,
#   'marketCap': 2873032441856,
#   'forwardPE': 32.78731,
#   'priceToBook': 13.014693,
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 0,
#   'averageAnalystRating': '1.7 - Buy',
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'displayName': 'Microsoft',
#   'symbol': 'MSFT'}}

# %%
import pandas as pd
print(type(msft.__dict__))
print(type(msft))

temp = pd.DataFrame.
# Out:
# <class 'dict'>
# <class 'yfinance.ticker.Ticker'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8512\2602376050.py in ?()
#       1 import pandas as pd
#       2 print(type(msft.__dict__))
#       3 print(type(msft))
#       4
# ----> 5 temp = pd.DataFrame.from_dict(msft)
#       6 temp
#
# c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\pandas\core\frame.py in ?(cls, data, orient, dtype, columns)
#    1809                 f"Got '{orient}' instead"
#    1810             )
#    1811
#    1812         if orient != "tight":
# -> 1813             return cls(data, index=index, columns=columns, dtype=dtype)
#    1814         else:
#    1815             realdata = data["data"]
#    1816
#
# c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     837                 )
#     838         # For data is scalar
#     839         else:
#     840             if index is None or columns is None:
# --> 841                 raise ValueError("DataFrame constructor not properly called!")
#     842
#     843             index = ensure_index(index)
#     844             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
