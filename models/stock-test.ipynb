# %%
from Stock import Stock
stock = Stock('GOOG')
stock.plot_data()

# %%
from Stock import Stock  # Assuming Stock class is defined in Stock.py
from StockClustering import StockClustering  # Assuming StockClustering class is in StockClustering.py

# Create an instance of the Stock class for 'GOOG'
stock = Stock('GOOG')
stock.plot_data()

# Assuming the StockClustering class expects a DataFrame similar to the one used in the Stock class
# Create an instance of StockClustering class
# Replace 'path_to_data' with the actual path to your data file
stock_clustering = StockClustering(data_path='../data/data_pkls/nasdaq100.pkl')
stock_clustering.load_data()

# Use the same data as the Stock instance
stock_clustering.data = stock.get_data()

# Perform feature extraction, preprocessing, and clustering
stock_clustering.extract_features()
stock_clustering.preprocess_data()
stock_clustering.perform_clustering(num_clusters=3)

# Plot the extracted features and clustering results
stock_clustering.plot_features()
stock_clustering.plot_clusters()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 18
#      15 stock_clustering.data = stock.get_data()
#      17 # Perform feature extraction, preprocessing, and clustering
# ---> 18 stock_clustering.extract_features()
#      19 stock_clustering.preprocess_data()
#      20 stock_clustering.perform_clustering(num_clusters=3)
#
# File c:\Users\Rober\Desktop\AASD4010\models\StockClustering.py:32, in StockClustering.extract_features(self)
#      28 """
#      29 Extracts relevant features for each company.
#      30 """
#      31 self.features_df = pd.DataFrame()
# ---> 32 for company in self.data.columns.levels[0]:
#      33     company_data = self.data[company]
#      34     daily_returns = company_data['Adj Close'].pct_change()
#
# AttributeError: 'Index' object has no attribute 'levels'

# %%
arima_model = stock.fit_arima((5, 1, 0))
sarimax_model = stock.fit_sarimax((1, 1, 1), (1, 1, 1, 12))
# Out:
# c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
