# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr
yf.pdr_override()

# %%
#S&P 500 companies

x = pd.read_csv("../data/company_info/sp500.csv")
x.head()
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                   Biotechnology
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
y = x['Symbol']
chunks = 50
curr = 0 
y = list(y)
symbol_list = []
while curr < len(y):
    symbol_list.append(y[curr:curr+chunks])
    curr = curr + chunks

# %%
#TODO PUT IN LOOP

symbol_list[0]
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)
symbol_list
res = yf.download(symbol_list[0],group_by="ticker")
# Out:
# [*********************100%%**********************]  50 of 50 completed

# %%
res.to_pickle('./stock50.pkl')

# %%
res
# Out:
#                   GOOG                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 1962-01-02         NaN         NaN         NaN         NaN         NaN
# 1962-01-03         NaN         NaN         NaN         NaN         NaN
# 1962-01-04         NaN         NaN         NaN         NaN         NaN
# 1962-01-05         NaN         NaN         NaN         NaN         NaN
# 1962-01-08         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2024-01-08  138.000000  140.639999  137.880005  140.529999  140.529999
# 2024-01-09  140.059998  142.800003  139.789993  142.559998  142.559998
# 2024-01-10  142.520004  144.524994  142.460007  143.800003  143.800003
# 2024-01-11  144.895004  146.660004  142.214996  143.669998  143.669998
# 2024-01-12  144.339996  144.739899  143.360001  144.240005  144.240005
#
#                               ABNB                                      ...  \
#                 Volume        Open        High         Low       Close  ...
# Date                                                                    ...
# 1962-01-02         NaN         NaN         NaN         NaN         NaN  ...
# 1962-01-03         NaN         NaN         NaN         NaN         NaN  ...
# 1962-01-04         NaN         NaN         NaN         NaN         NaN  ...
# 1962-01-05         NaN         NaN         NaN         NaN         NaN  ...
# 1962-01-08         NaN         NaN         NaN         NaN         NaN  ...
# ...                ...         ...         ...         ...         ...  ...
# 2024-01-08  17645300.0  137.309998  140.250000  136.610001  140.080002  ...
# 2024-01-09  19579700.0  138.520004  139.539993  137.789993  139.529999  ...
# 2024-01-10  16641900.0  139.199997  140.824997  138.699997  139.759995  ...
# 2024-01-11  17471100.0  140.710007  141.199997  137.550003  139.449997  ...
# 2024-01-12  13710960.0  139.350006  140.990005  137.130005  137.139999  ...
#
#                   AMAT                                            MMM  \
#                    Low       Close   Adj Close     Volume        Open
# Date
# 1962-01-02         NaN         NaN         NaN        NaN    0.000000
# 1962-01-03         NaN         NaN         NaN        NaN    0.000000
# 1962-01-04         NaN         NaN         NaN        NaN    0.000000
# 1962-01-05         NaN         NaN         NaN        NaN    0.000000
# 1962-01-08         NaN         NaN         NaN        NaN    0.000000
# ...                ...         ...         ...        ...         ...
# 2024-01-08  149.720001  151.559998  151.559998  6515500.0  108.260002
# 2024-01-09  148.929993  151.029999  151.029999  5606700.0  108.199997
# 2024-01-10  148.240005  149.809998  149.809998  5035700.0  109.019997
# 2024-01-11  148.479996  151.949997  151.949997  5995600.0  108.300003
# 2024-01-12  150.369995  151.250000  151.250000  4075853.0  109.419998
#
#
#                   High         Low       Close   Adj Close   Volume
# Date
# 1962-01-02    4.250000    4.125000    4.156250    0.702820   212800
# 1962-01-03    4.187500    4.085938    4.187500    0.708105   422400
# 1962-01-04    4.257813    4.187500    4.187500    0.708105   212800
# 1962-01-05    4.171875    4.062500    4.078125    0.689609   315200
# 1962-01-08    4.085938    4.031250    4.054688    0.685646   334400
# ...                ...         ...         ...         ...      ...
# 2024-01-08  108.959999  107.589996  108.860001  108.860001  2119600
# 2024-01-09  109.300003  107.349998  109.099998  109.099998  2458000
# 2024-01-10  109.120003  107.839996  108.300003  108.300003  1999800
# 2024-01-11  109.000000  107.209999  108.919998  108.919998  2685800
# 2024-01-12  110.160004  107.889999  108.120003  108.120003  2913595
#
# [15615 rows x 300 columns]

# %%
import time
save_dict = {}
import json

for i in symbol_list[0]:
    save_dict[i] = yf.Ticker(i)
    time.sleep(1)
    with open('data.json', 'a+') as f:
        json.dump(save_dict, f)
# Out:
# 50

# %%
  # Replace with your actual symbol_list


save_dict = {}

for symbol in symbol_list[0][10:52]:
    print(symbol)
    tick = yf.Ticker(i)
    save_dict[symbol] = tick.info
# Out:
# APD
# ABNB
# AKAM
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AAL
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# AME
# AMGN
# APH
# ADI
# ANSS
# AON
# APA
# AAPL
# AMAT
# APTV
# ACGL
# ADM
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK

# %%
save_dict
# Out:
# {'MMM': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None},
#  'AOS': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None},
#  'ABT': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None},
#  'ABBV': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None},
#  'ACN': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None},
#  'ADBE': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None},
#  'AMD': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None},
#  'AES': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None},
#  'AFL': {'address1': '1200 Main Street',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'zip': '64105',
#   'country': 'United States',
#   'phone': '816 556 2200',
#   'website': 'https://investors.evergy.com',
#   'industry': 'Utilities - Regulated Electric',
#   'industryKey': 'utilities-regulated-electric',
#   'industryDisp': 'Utilities - Regulated Electric',
#   'sector': 'Utilities',
#   'sectorKey': 'utilities',
#   'sectorDisp': 'Utilities',
#   'longBusinessSummary': 'Evergy, Inc., together with its subsidiaries, engages in the generation, transmission, distribution, and sale of electricity in Kansas and Missouri, the United States. The company generates electricity through coal, hydroelectric, landfill gas, uranium, and natural gas and oil sources, as well as solar, wind, other renewable sources. It serves residences, commercial firms, industrials, municipalities, and other electric utilities. The company was incorporated in 2017 and is headquartered in Kansas City, Missouri.',
#   'fullTimeEmployees': 4512,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. David A. Campbell',
#     'age': 55,
#     'title': 'President, CEO & Director',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 2573650,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kirkland B. Andrews',
#     'age': 55,
#     'title': 'Executive VP & CFO',
#     'yearBorn': 1968,
#     'fiscalYear': 2022,
#     'totalPay': 1684138,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevin E. Bryant',
#     'age': 47,
#     'title': 'Executive VP & COO',
#     'yearBorn': 1976,
#     'fiscalYear': 2022,
#     'totalPay': 1305855,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Heather A. Humphrey',
#     'age': 52,
#     'title': 'Senior VP, General Counsel & Corporate Secretary',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'totalPay': 1003121,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles A. Caisley',
#     'age': 50,
#     'title': 'Senior VP of Public Affairs & Chief Customer Officer',
#     'yearBorn': 1973,
#     'fiscalYear': 2022,
#     'totalPay': 969103,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Steven P. Busser',
#     'age': 54,
#     'title': 'VP & Chief Accounting Officer',
#     'yearBorn': 1969,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Charles L. King',
#     'age': 58,
#     'title': 'Senior VP & CTO',
#     'yearBorn': 1965,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Peter Francis Flynn',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Lesley Lissette Elwell',
#     'age': 52,
#     'title': 'Senior VP, Chief Human Resources Officer & Chief Diversity Officer',
#     'yearBorn': 1971,
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Cleveland O. Reasoner III',
#     'title': 'VP & Chief Nuclear Officer',
#     'fiscalYear': 2022,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 5,
#   'compensationRisk': 1,
#   'shareHolderRightsRisk': 3,
#   'overallRisk': 1,
#   'governanceEpochDate': 1704067200,
#   'compensationAsOfEpochDate': 1672444800,
#   'maxAge': 86400,
#   'priceHint': 2,
#   'previousClose': 53.35,
#   'open': 53.72,
#   'dayLow': 53.31,
#   'dayHigh': 54.02,
#   'regularMarketPreviousClose': 53.35,
#   'regularMarketOpen': 53.72,
#   'regularMarketDayLow': 53.31,
#   'regularMarketDayHigh': 54.02,
#   'dividendRate': 2.57,
#   'dividendYield': 0.0482,
#   'exDividendDate': 1700524800,
#   'payoutRatio': 0.82769996,
#   'fiveYearAvgDividendYield': 3.54,
#   'beta': 0.554,
#   'trailingPE': 18.192566,
#   'forwardPE': 14.0234375,
#   'volume': 2157816,
#   'regularMarketVolume': 2157816,
#   'averageVolume': 2811536,
#   'averageVolume10days': 2421360,
#   'averageDailyVolume10Day': 2421360,
#   'bid': 53.53,
#   'ask': 53.92,
#   'bidSize': 1100,
#   'askSize': 800,
#   'marketCap': 12370475008,
#   'fiftyTwoWeekLow': 46.92,
#   'fiftyTwoWeekHigh': 63.93,
#   'priceToSalesTrailing12Months': 2.2090528,
#   'fiftyDayAverage': 51.415,
#   'twoHundredDayAverage': 55.8153,
#   'trailingAnnualDividendRate': 2.45,
#   'trailingAnnualDividendYield': 0.04592315,
#   'currency': 'USD',
#   'enterpriseValue': 24993802240,
#   'profitMargins': 0.12157,
#   'floatShares': 228712283,
#   'sharesOutstanding': 229720992,
#   'sharesShort': 7567085,
#   'sharesShortPriorMonth': 4198941,
#   'sharesShortPreviousMonthDate': 1701302400,
#   'dateShortInterest': 1703808000,
#   'sharesPercentSharesOut': 0.032899998,
#   'heldPercentInsiders': 0.00199,
#   'heldPercentInstitutions': 0.86622,
#   'shortRatio': 2.3,
#   'shortPercentOfFloat': 0.0383,
#   'impliedSharesOutstanding': 229720992,
#   'bookValue': 42.439,
#   'priceToBook': 1.26888,
#   'lastFiscalYearEnd': 1672444800,
#   'nextFiscalYearEnd': 1703980800,
#   'mostRecentQuarter': 1696032000,
#   'earningsQuarterlyGrowth': -0.179,
#   'netIncomeToCommon': 680800000,
#   'trailingEps': 2.96,
#   'forwardEps': 3.84,
#   'pegRatio': 5.91,
#   'lastSplitFactor': '2:1',
#   'lastSplitDate': 548640000,
#   'enterpriseToRevenue': 4.463,
#   'enterpriseToEbitda': 10.977,
#   '52WeekChange': -0.14735496,
#   'SandP52WeekChange': 0.19776392,
#   'lastDividendValue': 0.643,
#   'lastDividendDate': 1700524800,
#   'exchange': 'NMS',
#   'quoteType': 'EQUITY',
#   'symbol': 'EVRG',
#   'underlyingSymbol': 'EVRG',
#   'shortName': 'Evergy, Inc.',
#   'longName': 'Evergy, Inc.',
#   'firstTradeDateEpochUtc': 99153000,
#   'timeZoneFullName': 'America/New_York',
#   'timeZoneShortName': 'EST',
#   'uuid': '62adc2ab-b034-316c-b95f-499a9fa33dcd',
#   'messageBoardId': 'finmb_283024',
#   'gmtOffSetMilliseconds': -18000000,
#   'currentPrice': 53.85,
#   'targetHighPrice': 60.0,
#   'targetLowPrice': 50.0,
#   'targetMeanPrice': 54.33,
#   'targetMedianPrice': 54.5,
#   'recommendationMean': 2.3,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 6,
#   'totalCash': 41000000,
#   'totalCashPerShare': 0.178,
#   'ebitda': 2276900096,
#   'totalDebt': 12760399872,
#   'quickRatio': 0.08,
#   'currentRatio': 0.394,
#   'totalRevenue': 5599900160,
#   'debtToEquity': 130.637,
#   'revenuePerShare': 24.35,
#   'returnOnAssets': 0.02466,
#   'returnOnEquity': 0.07152,
#   'grossProfits': 2634100000,
#   'freeCashflow': -488237504,
#   'operatingCashflow': 1875900032,
#   'earningsGrowth': -0.178,
#   'revenueGrowth': -0.126,
#   'grossMargins': 0.47804,
#   'ebitdaMargins': 0.4066,
#   'operatingMargins': 0.28725,
#   'financialCurrency': 'USD',
#   'trailingPegRatio': None}}

# %%
import json
with open('data2.json', 'w') as f:
    json.dump(save_dict, f)
