# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr
yf.pdr_override()

# %%
#S&P 500 companies

x = pd.read_csv("../data/company_info/sp500.csv")
x.head()
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                   Biotechnology
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
y = x['Symbol']
chunks = 50
curr = 0 
y = list(y)
symbol_list = []
while curr < len(y):
    symbol_list.append(y[curr:curr+chunks])
    curr = curr + chunks

# %%
#TODO PUT IN LOOP

symbol_list[0]
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)
symbol_list
res = yf.download(symbol_list[0],group_by="ticker")
# Out:
# [*********************100%%**********************]  50 of 50 completed

# %%
res.to_pickle('./stock50.pkl')

# %%
res
# Out:
#                   GOOG                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 1962-01-02         NaN         NaN         NaN         NaN         NaN
# 1962-01-03         NaN         NaN         NaN         NaN         NaN
# 1962-01-04         NaN         NaN         NaN         NaN         NaN
# 1962-01-05         NaN         NaN         NaN         NaN         NaN
# 1962-01-08         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2024-01-08  138.000000  140.639999  137.880005  140.529999  140.529999
# 2024-01-09  140.059998  142.800003  139.789993  142.559998  142.559998
# 2024-01-10  142.520004  144.524994  142.460007  143.800003  143.800003
# 2024-01-11  144.895004  146.660004  142.214996  143.669998  143.669998
# 2024-01-12  144.339996  144.739899  143.360001  144.240005  144.240005
#
# ...

# %%
import time
save_dict = {}
import json

for i in symbol_list[0]:
    save_dict[i] = yf.Ticker(i)
    time.sleep(1)
    with open('data.json', 'a+') as f:
        json.dump(save_dict, f)
# Out:
# 50

# %%
  # Replace with your actual symbol_list


save_dict = {}

for symbol in symbol_list[0]:
    print(symbol)
    tick = yf.Ticker(symbol)
    save_dict[symbol] = tick.info
# Out:
# MMM
# AOS
# ABT
# ABBV
# ACN
# ADBE
# AMD
# AES
# AFL
# A
# APD
# ABNB
# AKAM
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AAL
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# AME
# AMGN
# APH
# ADI
# ANSS
# AON
# APA
# AAPL
# AMAT
# APTV
# ACGL
# ADM
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK

# %%
save_dict
# Out:
# {'MMM': {'address1': '3M Center',
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'zip': '55144-1000',
#   'country': 'United States',
#   'phone': '651 733 1110',
#   'website': 'https://www.3m.com',
#   'industry': 'Conglomerates',
#   'industryKey': 'conglomerates',
#   'industryDisp': 'Conglomerates',
#   'sector': 'Industrials',
#   'sectorKey': 'industrials',
#   'sectorDisp': 'Industrials',
# ...

# %%
import json
with open('./data2.json', 'w') as f:
    json.dump(save_dict, f)

# %%
tick = yf.Ticker('GOOGL')

# %% [markdown]
# ds

# %%
save_dict
# Out:
# {'MMM': {'address1': '3M Center',
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'zip': '55144-1000',
#   'country': 'United States',
#   'phone': '651 733 1110',
#   'website': 'https://www.3m.com',
#   'industry': 'Conglomerates',
#   'industryKey': 'conglomerates',
#   'industryDisp': 'Conglomerates',
#   'sector': 'Industrials',
#   'sectorKey': 'industrials',
#   'sectorDisp': 'Industrials',
# ...

# %%
tick.info
# Out:
# {'address1': '1600 Amphitheatre Parkway',
#  'city': 'Mountain View',
#  'state': 'CA',
#  'zip': '94043',
#  'country': 'United States',
#  'phone': '650 253 0000',
#  'website': 'https://www.abc.xyz',
#  'industry': 'Internet Content & Information',
#  'industryKey': 'internet-content-information',
#  'industryDisp': 'Internet Content & Information',
#  'sector': 'Communication Services',
#  'sectorKey': 'communication-services',
#  'sectorDisp': 'Communication Services',
# ...
