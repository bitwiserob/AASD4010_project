# %%
from single_preprocessing_function import single_preprocessing
from LSTM_single_ticker_regression import single_ticker_LSTM_regression
from LSTM_pipeline import demonstrate_lstm_pipeline,lstm_hyperparameter_tuning
from LSTMModel import LSTMModel
from keras.utils import plot_model
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from keras import layers, optimizers
from keras.models import Sequential
from keras.layers import Dropout
import matplotlib.pyplot as plt
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow.keras.utils import plot_model

# %%
from stock.Stock import Stock
stock = Stock('GOOG')
stock.calculate_sma(20)
stock.calculate_ema(50)
stock.plot_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from stock.Stock import Stock
#       2 stock = Stock('GOOG')
#       3 stock.calculate_sma(20)
#
# ModuleNotFoundError: No module named 'stock'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from Stock import Stock
# ----> 4 stock = Stock('GOOG')
#
# File c:\Users\Rober\Desktop\AASD4010\regression\Stock.py:11, in Stock.__init__(self, ticker, start_date, end_date)
#       9 self.data = None
#      10 self.features = {}
# ---> 11 self.load_data()
#
# File c:\Users\Rober\Desktop\AASD4010\regression\Stock.py:14, in Stock.load_data(self)
#      13 def load_data(self):
# ---> 14     df = pd.read_pickle("./data/data_pkls/nasdaq100.pkl")
#      15     stock_data = df.get(self.ticker, pd.DataFrame())
#      17     if self.start_date is not None:
#
# File c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\pandas\io\pickle.py:189, in read_pickle(filepath_or_buffer, compression, storage_options)
#     125 """
#     126 Load pickled pandas object (or any object) from file.
#     127
# ...

# %%
lstm_model = LSTMModel()
lstm_model.demonstrate_lstm_pipeline()
# Out:
# c:\Users\Rober\Desktop\AASD4010\regression\single_preprocessing_function.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_y = [ y[i+delay+lag] for i in range(0, (y.shape[0]-(delay+lag)), delay)]
# Dimension check passed
# Shape of X: (944, 5, 4)
# Shape of y: (944,)
# 2nd Dimension check passed
# Epoch 1/190
# 21/21 [==============================] - 2s 25ms/step - loss: 2488.4119 - val_loss: 2581.8123
# Epoch 2/190
# 21/21 [==============================] - 0s 5ms/step - loss: 2114.6409 - val_loss: 2074.3987
# Epoch 3/190
# 21/21 [==============================] - 0s 5ms/step - loss: 1866.2506 - val_loss: 1982.2264
# Epoch 4/190
# 21/21 [==============================] - 0s 5ms/step - loss: 1786.7047 - val_loss: 1890.1511
# Epoch 5/190
# ...

# %%
plot_model(lstm_model.model,'img.jpg')

# %%
plot_model(lstm_model.model,'img.jpg')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# Define Parameter Grid with Learning Rate and Optimizer
param_grid = {
    'units': [50, 100],
    'dropout_rate': [0.2, 0.3],
    'learning_rate': [0.001, 0.01],
    'optimizer': ['adam', 'sgd']
}

# Instantiate LSTMModel
lstm_model = LSTMModel(units=50, dropout_rate=0.2)
lstm_model.preprocess_data()
# Perform Manual Grid Search
best_hyperparameters = lstm_model.manual_grid_search(param_grid, epochs=100, batch_size=32)

# Perform Manual Grid Search
search_results = lstm_model.manual_grid_search(param_grid, epochs=100, batch_size=32)

for result in search_results:
    print("Parameters:", result['params'])
    print("MSE:", result['mse'])
    print("MAPE:", result['mape'], "\n")
# Out:
# Dimension check passed
# Shape of X: (944, 5, 4)
# Shape of y: (944,)
# 2nd Dimension check passed
# WARNING:tensorflow:From c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# c:\Users\Rober\Desktop\AASD4010\regression\single_preprocessing_function.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_y = [ y[i+delay+lag] for i in range(0, (y.shape[0]-(delay+lag)), delay)]
# WARNING:tensorflow:From c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# ...
