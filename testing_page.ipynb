# %%
import dash
from dash import Dash, html, dcc, callback, Output, Input
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px
from models.Stock import Stock
from models.LSTMModel import LSTMModel
import dash_bootstrap_components as dbc
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
# Out:
# WARNING:tensorflow:From c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
stock_model = LSTMModel('GOOG', units=70, dropout_rate=0.2, epochs=100, batch_size=32)
stock_model.preprocess_data()
stock_model.build_lstm_model()
stock_model.train_lstm_model()
forecasted_values = stock_model.forecast(steps=7)
# Out:
# WARNING:tensorflow:From c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# c:\Users\Rober\Desktop\AASD4010\regression\single_preprocessing_function.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_y = [ y[i+delay+lag] for i in range(0, (y.shape[0]-(delay+lag)), delay)]
# WARNING:tensorflow:From c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/190
# ...

# %%
loaded_model = LSTMModel('GOOG')
loaded_model.load_model('model.h5')
loaded_model.preprocess_data()  # This loads and preprocesses the data
print("Shape of X_test:", loaded_model.X_test.shape)
# Out:
# WARNING:tensorflow:From c:\Users\Rober\.virtualenvs\AASD4010-XSwstjEU\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Shape of X_test: (196, 5, 4)
# c:\Users\Rober\Desktop\AASD4010\regression\single_preprocessing_function.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_y = [ y[i+delay+lag] for i in range(0, (y.shape[0]-(delay+lag)), delay)]

# %%
forecasted_values = loaded_model.forecast(steps=7)
print(loaded_model)
# Out:
# ...
# 1/1 [==============================] - 0s 14ms/step
# [129.71632, 129.71632, 129.71632, 129.71632, 129.71632, 129.71632, 129.71632]
# ...
